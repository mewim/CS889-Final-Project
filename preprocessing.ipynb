# %% [markdown]
# In this first notebook, I am using Spotify data to see which songs are similar to a given song. Similar songs are simply those songs which are close to the vector embedding of the given song. I construct the vector embedding using (scaled version of) attributes like "acousticness", ..., "valence".

# %%
import numpy as np
import pandas as pd
import glob
import tqdm
from collections import OrderedDict
import langid # I want english songs

# %%
csv = pd.read_csv(*glob.glob("public/data/tracks.csv"))

# %%
def scale_0_1(df, col):
    df.loc[:, col] = (df[col]-df[col].mean())/df[col].std()

# %%
attrs = ["acousticness", "danceability", "energy", "instrumentalness", "liveness", "loudness", "speechiness", "tempo", "valence"]
for attr in attrs:
    scale_0_1(csv, attr) # Rescale these attributes to be N(0, 1)
csv.loc[:, "name"] = csv["name"].str.lower()
csv = csv.drop_duplicates(subset=attrs)

# %%
# langid.classify is a fast way to check the language of the song name
def check_en(name):
    try:
        return langid.classify(name)[0] in ["en"]
    except:
        return False

tqdm.tqdm.pandas()
csv = csv[csv["name"].progress_apply(lambda x: check_en(x))]
# Out:
# 100%|██████████| 566113/566113 [07:06<00:00, 1325.91it/s]

# %%
song_name = "i'll do anything"
rows = csv[["name", "id", "artists"]+attrs][csv["name"].str.contains(song_name)]
vec = rows[attrs].iloc[2].to_numpy()
rows
# Out:
#                             name                      id            artists  \
# 56455   i'll do anything for you  3CuKcfH8BJ5The5G3llaKD  ['Denroy Morgan']
# 458469          i'll do anything  2mmqUU64P1BhJNvH1jtofT        ['D-Train']
# 555315          i'll do anything  0hK8yn7I0oqrqXljVVGPla     ['Jason Mraz']
#
#         acousticness  danceability    energy  instrumentalness  liveness  \
# 56455      -0.730608      1.013868  1.091461         -0.425109 -0.713601
# 458469     -1.164622      1.519579  0.075277         -0.425099 -0.817765
# 555315     -0.948475      0.038568  0.670697         -0.425120  0.749028
#
#         loudness  speechiness     tempo   valence
# 56455   0.714253     1.006913 -0.110027  0.976856
# 458469  0.149738    -0.155446  0.047277  0.775049
# 555315  1.188775    -0.193246  1.500604  0.375314

# %%
csv2 = csv[["acousticness","danceability","energy","instrumentalness","valence","liveness","speechiness"]]

# %%
from sklearn.manifold import TSNE

# %%
csv2.to_numpy().shape
# Out:
# (215035, 7)

# %%
X_embedded = TSNE(n_components=2, verbose=1, n_jobs=8).fit_transform(csv2.to_numpy())
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 215035 samples in 0.378s...
# [t-SNE] Computed neighbors for 215035 samples in 41.898s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 215035
# [t-SNE] Computed conditional probabilities for sample 2000 / 215035
# [t-SNE] Computed conditional probabilities for sample 3000 / 215035
# [t-SNE] Computed conditional probabilities for sample 4000 / 215035
# [t-SNE] Computed conditional probabilities for sample 5000 / 215035
# [t-SNE] Computed conditional probabilities for sample 6000 / 215035
# [t-SNE] Computed conditional probabilities for sample 7000 / 215035
# [t-SNE] Computed conditional probabilities for sample 8000 / 215035
# [t-SNE] Computed conditional probabilities for sample 9000 / 215035
# [t-SNE] Computed conditional probabilities for sample 10000 / 215035
# [t-SNE] Computed conditional probabilities for sample 11000 / 215035
# [t-SNE] Computed conditional probabilities for sample 12000 / 215035
# [t-SNE] Computed conditional probabilities for sample 13000 / 215035
# [t-SNE] Computed conditional probabilities for sample 14000 / 215035
# [t-SNE] Computed conditional probabilities for sample 15000 / 215035
# [t-SNE] Computed conditional probabilities for sample 16000 / 215035
# [t-SNE] Computed conditional probabilities for sample 17000 / 215035
# [t-SNE] Computed conditional probabilities for sample 18000 / 215035
# [t-SNE] Computed conditional probabilities for sample 19000 / 215035
# [t-SNE] Computed conditional probabilities for sample 20000 / 215035
# [t-SNE] Computed conditional probabilities for sample 21000 / 215035
# [t-SNE] Computed conditional probabilities for sample 22000 / 215035
# [t-SNE] Computed conditional probabilities for sample 23000 / 215035
# [t-SNE] Computed conditional probabilities for sample 24000 / 215035
# [t-SNE] Computed conditional probabilities for sample 25000 / 215035
# [t-SNE] Computed conditional probabilities for sample 26000 / 215035
# [t-SNE] Computed conditional probabilities for sample 27000 / 215035
# [t-SNE] Computed conditional probabilities for sample 28000 / 215035
# [t-SNE] Computed conditional probabilities for sample 29000 / 215035
# [t-SNE] Computed conditional probabilities for sample 30000 / 215035
# [t-SNE] Computed conditional probabilities for sample 31000 / 215035
# [t-SNE] Computed conditional probabilities for sample 32000 / 215035
# [t-SNE] Computed conditional probabilities for sample 33000 / 215035
# [t-SNE] Computed conditional probabilities for sample 34000 / 215035
# [t-SNE] Computed conditional probabilities for sample 35000 / 215035
# [t-SNE] Computed conditional probabilities for sample 36000 / 215035
# [t-SNE] Computed conditional probabilities for sample 37000 / 215035
# [t-SNE] Computed conditional probabilities for sample 38000 / 215035
# [t-SNE] Computed conditional probabilities for sample 39000 / 215035
# [t-SNE] Computed conditional probabilities for sample 40000 / 215035
# [t-SNE] Computed conditional probabilities for sample 41000 / 215035
# [t-SNE] Computed conditional probabilities for sample 42000 / 215035
# [t-SNE] Computed conditional probabilities for sample 43000 / 215035
# [t-SNE] Computed conditional probabilities for sample 44000 / 215035
# [t-SNE] Computed conditional probabilities for sample 45000 / 215035
# [t-SNE] Computed conditional probabilities for sample 46000 / 215035
# [t-SNE] Computed conditional probabilities for sample 47000 / 215035
# [t-SNE] Computed conditional probabilities for sample 48000 / 215035
# [t-SNE] Computed conditional probabilities for sample 49000 / 215035
# [t-SNE] Computed conditional probabilities for sample 50000 / 215035
# [t-SNE] Computed conditional probabilities for sample 51000 / 215035
# [t-SNE] Computed conditional probabilities for sample 52000 / 215035
# [t-SNE] Computed conditional probabilities for sample 53000 / 215035
# [t-SNE] Computed conditional probabilities for sample 54000 / 215035
# [t-SNE] Computed conditional probabilities for sample 55000 / 215035
# [t-SNE] Computed conditional probabilities for sample 56000 / 215035
# [t-SNE] Computed conditional probabilities for sample 57000 / 215035
# [t-SNE] Computed conditional probabilities for sample 58000 / 215035
# [t-SNE] Computed conditional probabilities for sample 59000 / 215035
# [t-SNE] Computed conditional probabilities for sample 60000 / 215035
# [t-SNE] Computed conditional probabilities for sample 61000 / 215035
# [t-SNE] Computed conditional probabilities for sample 62000 / 215035
# [t-SNE] Computed conditional probabilities for sample 63000 / 215035
# [t-SNE] Computed conditional probabilities for sample 64000 / 215035
# [t-SNE] Computed conditional probabilities for sample 65000 / 215035
# [t-SNE] Computed conditional probabilities for sample 66000 / 215035
# [t-SNE] Computed conditional probabilities for sample 67000 / 215035
# [t-SNE] Computed conditional probabilities for sample 68000 / 215035
# [t-SNE] Computed conditional probabilities for sample 69000 / 215035
# [t-SNE] Computed conditional probabilities for sample 70000 / 215035
# [t-SNE] Computed conditional probabilities for sample 71000 / 215035
# [t-SNE] Computed conditional probabilities for sample 72000 / 215035
# [t-SNE] Computed conditional probabilities for sample 73000 / 215035
# [t-SNE] Computed conditional probabilities for sample 74000 / 215035
# [t-SNE] Computed conditional probabilities for sample 75000 / 215035
# [t-SNE] Computed conditional probabilities for sample 76000 / 215035
# [t-SNE] Computed conditional probabilities for sample 77000 / 215035
# [t-SNE] Computed conditional probabilities for sample 78000 / 215035
# [t-SNE] Computed conditional probabilities for sample 79000 / 215035
# [t-SNE] Computed conditional probabilities for sample 80000 / 215035
# [t-SNE] Computed conditional probabilities for sample 81000 / 215035
# [t-SNE] Computed conditional probabilities for sample 82000 / 215035
# [t-SNE] Computed conditional probabilities for sample 83000 / 215035
# [t-SNE] Computed conditional probabilities for sample 84000 / 215035
# [t-SNE] Computed conditional probabilities for sample 85000 / 215035
# [t-SNE] Computed conditional probabilities for sample 86000 / 215035
# [t-SNE] Computed conditional probabilities for sample 87000 / 215035
# [t-SNE] Computed conditional probabilities for sample 88000 / 215035
# [t-SNE] Computed conditional probabilities for sample 89000 / 215035
# [t-SNE] Computed conditional probabilities for sample 90000 / 215035
# [t-SNE] Computed conditional probabilities for sample 91000 / 215035
# [t-SNE] Computed conditional probabilities for sample 92000 / 215035
# [t-SNE] Computed conditional probabilities for sample 93000 / 215035
# [t-SNE] Computed conditional probabilities for sample 94000 / 215035
# [t-SNE] Computed conditional probabilities for sample 95000 / 215035
# [t-SNE] Computed conditional probabilities for sample 96000 / 215035
# [t-SNE] Computed conditional probabilities for sample 97000 / 215035
# [t-SNE] Computed conditional probabilities for sample 98000 / 215035
# [t-SNE] Computed conditional probabilities for sample 99000 / 215035
# [t-SNE] Computed conditional probabilities for sample 100000 / 215035
# [t-SNE] Computed conditional probabilities for sample 101000 / 215035
# [t-SNE] Computed conditional probabilities for sample 102000 / 215035
# [t-SNE] Computed conditional probabilities for sample 103000 / 215035
# [t-SNE] Computed conditional probabilities for sample 104000 / 215035
# [t-SNE] Computed conditional probabilities for sample 105000 / 215035
# [t-SNE] Computed conditional probabilities for sample 106000 / 215035
# [t-SNE] Computed conditional probabilities for sample 107000 / 215035
# [t-SNE] Computed conditional probabilities for sample 108000 / 215035
# [t-SNE] Computed conditional probabilities for sample 109000 / 215035
# [t-SNE] Computed conditional probabilities for sample 110000 / 215035
# [t-SNE] Computed conditional probabilities for sample 111000 / 215035
# [t-SNE] Computed conditional probabilities for sample 112000 / 215035
# [t-SNE] Computed conditional probabilities for sample 113000 / 215035
# [t-SNE] Computed conditional probabilities for sample 114000 / 215035
# [t-SNE] Computed conditional probabilities for sample 115000 / 215035
# [t-SNE] Computed conditional probabilities for sample 116000 / 215035
# [t-SNE] Computed conditional probabilities for sample 117000 / 215035
# [t-SNE] Computed conditional probabilities for sample 118000 / 215035
# [t-SNE] Computed conditional probabilities for sample 119000 / 215035
# [t-SNE] Computed conditional probabilities for sample 120000 / 215035
# [t-SNE] Computed conditional probabilities for sample 121000 / 215035
# [t-SNE] Computed conditional probabilities for sample 122000 / 215035
# [t-SNE] Computed conditional probabilities for sample 123000 / 215035
# [t-SNE] Computed conditional probabilities for sample 124000 / 215035
# [t-SNE] Computed conditional probabilities for sample 125000 / 215035
# [t-SNE] Computed conditional probabilities for sample 126000 / 215035
# [t-SNE] Computed conditional probabilities for sample 127000 / 215035
# [t-SNE] Computed conditional probabilities for sample 128000 / 215035
# [t-SNE] Computed conditional probabilities for sample 129000 / 215035
# [t-SNE] Computed conditional probabilities for sample 130000 / 215035
# [t-SNE] Computed conditional probabilities for sample 131000 / 215035
# [t-SNE] Computed conditional probabilities for sample 132000 / 215035
# [t-SNE] Computed conditional probabilities for sample 133000 / 215035
# [t-SNE] Computed conditional probabilities for sample 134000 / 215035
# [t-SNE] Computed conditional probabilities for sample 135000 / 215035
# [t-SNE] Computed conditional probabilities for sample 136000 / 215035
# [t-SNE] Computed conditional probabilities for sample 137000 / 215035
# [t-SNE] Computed conditional probabilities for sample 138000 / 215035
# [t-SNE] Computed conditional probabilities for sample 139000 / 215035
# [t-SNE] Computed conditional probabilities for sample 140000 / 215035
# [t-SNE] Computed conditional probabilities for sample 141000 / 215035
# [t-SNE] Computed conditional probabilities for sample 142000 / 215035
# [t-SNE] Computed conditional probabilities for sample 143000 / 215035
# [t-SNE] Computed conditional probabilities for sample 144000 / 215035
# [t-SNE] Computed conditional probabilities for sample 145000 / 215035
# [t-SNE] Computed conditional probabilities for sample 146000 / 215035
# [t-SNE] Computed conditional probabilities for sample 147000 / 215035
# [t-SNE] Computed conditional probabilities for sample 148000 / 215035
# [t-SNE] Computed conditional probabilities for sample 149000 / 215035
# [t-SNE] Computed conditional probabilities for sample 150000 / 215035
# [t-SNE] Computed conditional probabilities for sample 151000 / 215035
# [t-SNE] Computed conditional probabilities for sample 152000 / 215035
# [t-SNE] Computed conditional probabilities for sample 153000 / 215035
# [t-SNE] Computed conditional probabilities for sample 154000 / 215035
# [t-SNE] Computed conditional probabilities for sample 155000 / 215035
# [t-SNE] Computed conditional probabilities for sample 156000 / 215035
# [t-SNE] Computed conditional probabilities for sample 157000 / 215035
# [t-SNE] Computed conditional probabilities for sample 158000 / 215035
# [t-SNE] Computed conditional probabilities for sample 159000 / 215035
# [t-SNE] Computed conditional probabilities for sample 160000 / 215035
# [t-SNE] Computed conditional probabilities for sample 161000 / 215035
# [t-SNE] Computed conditional probabilities for sample 162000 / 215035
# [t-SNE] Computed conditional probabilities for sample 163000 / 215035
# [t-SNE] Computed conditional probabilities for sample 164000 / 215035
# [t-SNE] Computed conditional probabilities for sample 165000 / 215035
# [t-SNE] Computed conditional probabilities for sample 166000 / 215035
# [t-SNE] Computed conditional probabilities for sample 167000 / 215035
# [t-SNE] Computed conditional probabilities for sample 168000 / 215035
# [t-SNE] Computed conditional probabilities for sample 169000 / 215035
# [t-SNE] Computed conditional probabilities for sample 170000 / 215035
# [t-SNE] Computed conditional probabilities for sample 171000 / 215035
# [t-SNE] Computed conditional probabilities for sample 172000 / 215035
# [t-SNE] Computed conditional probabilities for sample 173000 / 215035
# [t-SNE] Computed conditional probabilities for sample 174000 / 215035
# [t-SNE] Computed conditional probabilities for sample 175000 / 215035
# [t-SNE] Computed conditional probabilities for sample 176000 / 215035
# [t-SNE] Computed conditional probabilities for sample 177000 / 215035
# [t-SNE] Computed conditional probabilities for sample 178000 / 215035
# [t-SNE] Computed conditional probabilities for sample 179000 / 215035
# [t-SNE] Computed conditional probabilities for sample 180000 / 215035
# [t-SNE] Computed conditional probabilities for sample 181000 / 215035
# [t-SNE] Computed conditional probabilities for sample 182000 / 215035
# [t-SNE] Computed conditional probabilities for sample 183000 / 215035
# [t-SNE] Computed conditional probabilities for sample 184000 / 215035
# [t-SNE] Computed conditional probabilities for sample 185000 / 215035
# [t-SNE] Computed conditional probabilities for sample 186000 / 215035
# [t-SNE] Computed conditional probabilities for sample 187000 / 215035
# [t-SNE] Computed conditional probabilities for sample 188000 / 215035
# [t-SNE] Computed conditional probabilities for sample 189000 / 215035
# [t-SNE] Computed conditional probabilities for sample 190000 / 215035
# [t-SNE] Computed conditional probabilities for sample 191000 / 215035
# [t-SNE] Computed conditional probabilities for sample 192000 / 215035
# [t-SNE] Computed conditional probabilities for sample 193000 / 215035
# [t-SNE] Computed conditional probabilities for sample 194000 / 215035
# [t-SNE] Computed conditional probabilities for sample 195000 / 215035
# [t-SNE] Computed conditional probabilities for sample 196000 / 215035
# [t-SNE] Computed conditional probabilities for sample 197000 / 215035
# [t-SNE] Computed conditional probabilities for sample 198000 / 215035
# [t-SNE] Computed conditional probabilities for sample 199000 / 215035
# [t-SNE] Computed conditional probabilities for sample 200000 / 215035
# [t-SNE] Computed conditional probabilities for sample 201000 / 215035
# [t-SNE] Computed conditional probabilities for sample 202000 / 215035
# [t-SNE] Computed conditional probabilities for sample 203000 / 215035
# [t-SNE] Computed conditional probabilities for sample 204000 / 215035
# [t-SNE] Computed conditional probabilities for sample 205000 / 215035
# [t-SNE] Computed conditional probabilities for sample 206000 / 215035
# [t-SNE] Computed conditional probabilities for sample 207000 / 215035
# [t-SNE] Computed conditional probabilities for sample 208000 / 215035
# [t-SNE] Computed conditional probabilities for sample 209000 / 215035
# [t-SNE] Computed conditional probabilities for sample 210000 / 215035
# [t-SNE] Computed conditional probabilities for sample 211000 / 215035
# [t-SNE] Computed conditional probabilities for sample 212000 / 215035
# [t-SNE] Computed conditional probabilities for sample 213000 / 215035
# [t-SNE] Computed conditional probabilities for sample 214000 / 215035
# [t-SNE] Computed conditional probabilities for sample 215000 / 215035
# [t-SNE] Computed conditional probabilities for sample 215035 / 215035
# [t-SNE] Mean sigma: 0.188698
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 134.191772
# [t-SNE] KL divergence after 1000 iterations: 4.488948

# %%
X_embedded.shape
# Out:
# (215035, 2)

# %%
csv3 = csv

# %%
csv3['x'] = X_embedded[:, 0].tolist()
csv3['y'] = X_embedded[:, 1].tolist()
# csv3['z'] = X_embedded[:, 2].tolist()

# %%
csv4 = csv3[csv3['popularity'] > 60]

# %%
csv4
# Out:
#                             id  \
# 8095    1LGqJ3nvxpVXDWpEzq4DJD
# 18549   0qB213IfGN0JXXm9aRjldF
# 21549   6yhLR2sVn1IfsScVrR4ocr
# 28498   6crfO56bDm0RjpctUuGs5X
# 28499   1uRKT2LRANv4baowBWHfDS
# ...                        ...
# 586657  1dKxf4Ht2SsKLyXfSDJAgy
# 586661  27kcZEJvhkb1rzZS9gCpdA
# 586665  0SjsIzJkZfDU7wlcdklEFR
# 586668  0NuWgxEp51CutD2pJoF4OM
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2
#
#                                                      name  popularity  \
# 8095                                            all of me          65
# 18549                           again (with the mellomen)          61
# 21549   whatever will be, will be (que sera, sera) (wi...          62
# 28498                            i'm in the mood for love          65
# 28499                 (we're gonna) rock around the clock          64
# ...                                                   ...         ...
# 586657                                   the cutest puppy          67
# 586661                              remember the mornings          67
# 586665                                  john brown's song          66
# 586668                                              blind          72
# 586669                          what they'll say about us          70
#
#         duration_ms  explicit                                       artists  \
# 8095         181440         0                            ['Billie Holiday']
# 18549        167907         0                 ['Doris Day', 'The Mellomen']
# 21549        123360         0  ['Doris Day', 'Frank DeVol & His Orchestra']
# 28498        149827         0                              ['Julie London']
# 28499        129893         0                   ['Bill Haley & His Comets']
# ...             ...       ...                                           ...
# 586657        82500         0                            ['Laureen Conrad']
# 586661       202355         0                              ['Clinton Kane']
# 586665       185250         0                            ['Gregory Oberle']
# 586668       153293         0                                ['ROLE MODEL']
# 586669       187601         0                                   ['FINNEAS']
#
#                                                id_artists release_date  \
# 8095                           ['1YzCsTRb22dQkh9lghPIrp']         1933
# 18549   ['3ESG6pj6a0LvUKklENalT6', '548L4DXlt7N14Mhbfd...         1945
# 21549   ['3ESG6pj6a0LvUKklENalT6', '2N0Yx2ISFxGV0yt7xf...         1948
# 28498                          ['3qUMmh5biaB5hqpF4LqS3m']   1955-12-01
# 28499                          ['3MFp4cYuYtTZe3d3xkLLbr']   1955-12-19
# ...                                                   ...          ...
# 586657                         ['7vgGpuiXdNlCmc994PlMlz']   2020-10-30
# 586661                         ['7okSU80WTrn4LXlyXYbX3P']   2020-11-27
# 586665                         ['4MxqhahGRT4BPz1PilXGeu']   2020-03-20
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
#
#         danceability    energy  ...  mode  speechiness  acousticness  \
# 8095       -0.358777 -1.895961  ...     0    -0.356121      1.496796
# 18549      -0.412960 -2.068633  ...     1    -0.389474      1.522596
# 21549      -0.888570 -0.798006  ...     1    -0.365571      1.187195
# 28498       0.098771 -1.935258  ...     0    -0.319988      1.470996
# 28499       1.489478  1.258178  ...     1     0.350967     -0.701941
# ...              ...       ...  ...   ...          ...           ...
# 586657      0.273362 -2.083320  ...     1     0.073024      1.565596
# 586661      0.158975 -0.393120  ...     1    -0.181572      0.481994
# 586665     -0.009595 -2.020205  ...     1    -0.010359      1.565596
# 586668      1.212540  0.480163  ...     1    -0.220484     -0.885408
# 586669     -0.172145 -0.905182  ...     0    -0.356121      1.276062
#
#         instrumentalness  liveness   valence     tempo  time_signature  \
# 8095           -0.425103 -0.216655 -0.579392 -0.385392               5
# 18549          -0.425115 -0.752120 -1.580669 -1.877323               4
# 21549          -0.425120  2.767196  0.868191  1.974329               4
# 28498          -0.424127 -0.636021 -1.456480  0.163826               4
# 28499          -0.425106 -0.747780  0.899238 -0.933301               4
# ...                  ...       ...       ...       ...             ...
# 586657          3.220879 -0.574717  1.310616 -1.674697               4
# 586661         -0.425120 -0.563866 -0.816128  1.040923               4
# 586665          3.175913 -0.558441 -0.645368 -1.840097               3
# 586668         -0.424007 -0.659350  0.518908  1.062560               4
# 586669         -0.424558 -0.686476 -1.886097  0.894707               4
#
#                 x          y
# 8095    29.339767 -24.890440
# 18549   25.575068 -28.437536
# 21549  -19.093706 -28.802057
# 28498   24.642628 -25.393911
# 28499   20.308483  26.988455
# ...           ...        ...
# 586657 -39.589260  11.519838
# 586661 -32.162075   3.090466
# 586665  -9.670913  42.119564
# 586668  25.317987  13.329927
# 586669 -38.480209  -1.364225
#
# [13839 rows x 22 columns]

# %%
min(csv3['popularity'].unique()), max(csv3['popularity'].unique())
# Out:
# (0, 99)

# %%
import scipy.cluster.hierarchy as hcluster

# %%
clusters = hcluster.fclusterdata(csv4[['x', 'y']].to_numpy(), 0.5, criterion="distance")

# %%
np.unique(clusters)
# Out:
# array([   1,    2,    3, ..., 2199, 2200, 2201], dtype=int32)

# %%
csv4['c'] = clusters.tolist()

# %%
csv4.to_csv("public/tracks13k.csv")

# %%
csv4.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'x', 'y'],
#       dtype='object')
